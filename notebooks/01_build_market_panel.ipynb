# %%
from quant.data.bloomberg import get_bbg_data

NAMES = {
    "SPX Index": "spx",
    "NDX Index": "ndx",
    "RTY Index": "rty",
    "VIX Index": "vix",
    "DXY Index": "dxy",
    "USGG2YR Index": "us2y",
    "USGG10YR Index": "us10y",
}
field_names = ["PX_LAST", "PX_OPEN", "PX_HIGH", "PX_LOW", "PX_VOLUME"]

panel = get_bbg_data(
    tickers=list(NAMES.keys()),
    fields=field_names,
    start_date="2025-12-01",
    end_date="2025-12-31",
    names=NAMES,
    flatten=True,
)

panel.head()
# Out:
#            SPX Index NDX Index RTY Index VIX Index DXY Index USGG2YR Index  \
#              PX_LAST   PX_LAST   PX_LAST   PX_LAST   PX_LAST       PX_LAST
# 2025-12-01   6812.63  25342.85  2469.129     17.24    99.414        3.5304
# 2025-12-02   6829.37  25555.86  2464.983     16.59    99.357        3.5080
# 2025-12-03   6849.72  25606.54  2512.136     16.08    98.854        3.4835
# 2025-12-04   6857.12  25581.70  2531.159     15.78    98.989        3.5226
# 2025-12-05   6870.40  25692.05  2521.484     15.41    98.992        3.5603
# 2025-12-08   6846.51  25627.95  2520.980     16.66    99.087        3.5750
# 2025-12-09   6840.51  25668.69  2526.245     16.93    99.220        3.6147
# 2025-12-10   6886.68  25776.44  2559.608     15.77    98.786        3.5381
# 2025-12-11   6901.00  25686.68  2590.605     14.85    98.346        3.5404
# 2025-12-12   6827.41  25196.73  2551.457     15.74    98.399        3.5222
# ...
