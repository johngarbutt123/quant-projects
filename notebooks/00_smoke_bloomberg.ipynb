# %%
from quant.data.bloomberg import get_bbg_data
from quant.analytics.returns import prices_to_returns

prices = get_bbg_data(
    ["AAPL US Equity", "MSFT US Equity"],
    ["PX_LAST"],
    "2023-01-01",
    "2023-12-31",
)

returns = prices_to_returns(prices, method="simple", dropna=True)

returns.describe()
display(returns)
# Out:
#            AAPL US Equity MSFT US Equity
#                   PX_LAST        PX_LAST
# 2023-01-04       0.010314      -0.043743
# 2023-01-05      -0.010605      -0.029638
# 2023-01-06       0.036794       0.011785
# 2023-01-09       0.004089       0.009736
# 2023-01-10       0.004456       0.007617
# ...                   ...            ...
# 2023-12-22      -0.005548       0.002784
# 2023-12-26      -0.002841       0.000214
# 2023-12-27       0.000518      -0.001575
# 2023-12-28       0.002226       0.003235
# 2023-12-29      -0.005424       0.002025
#
# [249 rows x 2 columns]
