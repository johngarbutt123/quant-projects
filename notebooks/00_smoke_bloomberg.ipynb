# %%
from quant.data.bloomberg import get_bbg_data

tickers = ["AAPL US Equity", "MSFT US Equity"]
fields = ["PX_LAST"]

df = get_bbg_data(
    tickers,
    fields,
    start_date="2023-01-01",
    end_date="2023-12-31",
)

df.head()
