# %%
import os
import pandas as pd
from quant.analytics.returns import prices_to_returns

os.chdir("..")

# %%
panel = pd.read_parquet("data/raw/market_panel_px_last.parquet").sort_index()
panel.head()
# Out:
#             spx-PX_LAST  ndx-PX_LAST  rty-PX_LAST  nikkei-PX_LAST  \
# 2007-01-01          NaN          NaN          NaN             NaN
# 2007-01-02          NaN          NaN          NaN             NaN
# 2007-01-03      1416.60      1759.37      787.436             NaN
# 2007-01-04      1418.34      1792.91      789.964        17353.67
# 2007-01-05      1409.71      1785.30      775.885        17091.59
#
#             ftse-PX_LAST  us2y-PX_LAST  us10y-PX_LAST  uk10y-PX_LAST  \
# 2007-01-01           NaN        4.8080         4.7022          4.741
# 2007-01-02        6310.9        4.7913         4.6802          4.758
# 2007-01-03        6319.0        4.7580         4.6582          4.787
# 2007-01-04        6287.0        4.6913         4.6024          4.773
# 2007-01-05        6220.1        4.7494         4.6442          4.802
#
#             bund10y-PX_LAST  ig_credit-PX_LAST  hy_credit-PX_LAST  \
# 2007-01-01              NaN                NaN                NaN
# ...

# %%
rets = prices_to_returns(panel, method="simple")
rets.head()
# Out:
#             spx-PX_LAST  ndx-PX_LAST  rty-PX_LAST  nikkei-PX_LAST  \
# 2007-01-02          NaN          NaN          NaN             NaN
# 2007-01-03          NaN          NaN          NaN             NaN
# 2007-01-04     0.001228     0.019064     0.003210             NaN
# 2007-01-05    -0.006085    -0.004244    -0.017822       -0.015102
# 2007-01-08     0.002220     0.001031     0.001455             NaN
#
#             ftse-PX_LAST  us2y-PX_LAST  us10y-PX_LAST  uk10y-PX_LAST  \
# 2007-01-02           NaN     -0.003473      -0.004679       0.003586
# 2007-01-03      0.001283     -0.006950      -0.004701       0.006095
# 2007-01-04     -0.005064     -0.014018      -0.011979      -0.002925
# 2007-01-05     -0.010641      0.012385       0.009082       0.006076
# 2007-01-08     -0.004164      0.005264       0.001723      -0.002707
#
#             bund10y-PX_LAST  ig_credit-PX_LAST  hy_credit-PX_LAST  \
# 2007-01-02              NaN                NaN                NaN
# ...
